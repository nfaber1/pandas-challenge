# %%
# Dependencies and Setup
import pandas as pd
from collections import OrderedDict 

# File to Load (Remember to Change These)
file_to_load = "04-Pandas_Homework_Instructions_HeroesOfPymoli_Resources_purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data#.head()
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %%
# sn_df = pd.DataFrame(purchase_data, columns= ['SN'])
sn_df1=purchase_data["SN"]#.count()
# sn_df1.values.tolist()
okay = list(set(sn_df1))
okay
# Out:
# ['Sausosia74',
#  'Filurarn35',
#  'Undassa89',
#  'Lisim51',
#  'Lisista27',
#  'Eulolis41',
#  'Lisadar44',
#  'Undirrasta89',
#  'Chanossanya44',
#  'Eodailis27',
#  'Assassa81',
#  'Undosian34',
#  'Ilassast39',
#  'Mindilsa60',
#  'Lisotesta51',
#  'Arirgue63',
#  'Idai61',
#  'Chadossa89',
#  'Chanirra64',
#  'Inasti31',
#  'Iarallo65',
#  'Undirrala66',
#  'Alaesu77',
#  'Hailaphos89',
#  'Pheosurllorin41',
#  'Pheutherin27',
#  'Iskim96',
#  'Siralsudeu54',
#  'Sally64',
#  'Jiskossa61',
#  'Sondastsda82',
#  'Haerith37',
#  'Haestyphos66',
#  'Fironon91',
#  'Asur53',
#  'Heunadil74',
#  'Aesty53',
#  'Eusur90',
#  'Sundirrala66',
#  'Iskosia90',
#  'Aisurria69',
#  'Aeralstical35',
#  'Chadossa56',
#  'Asty82',
#  'Eosrirgue62',
#  'Aesri53',
#  'Filrion59',
#  'Chanirrasta87',
#  'Iri67',
#  'Chamimla73',
#  'Iskim66',
#  'Saedaiphos46',
#  'Aidaillodeu39',
#  'Lisico81',
#  'Eodairu79',
#  'Undjask33',
#  'Malon70',
#  'Tyaerith73',
#  'Chamirrasya33',
#  'Marjask87',
#  'Jiskimsda56',
#  'Malarrian73',
#  'Lirtossa84',
#  'Firon67',
#  'Syalollorap93',
#  'Marynde90',
#  'Yarithrgue83',
#  'Idastidru52',
#  'Quanrion96',
#  'Tyialisti80',
#  'Saena89',
#  'Undista85',
#  'Heollyra92',
#  'Reulae52',
#  'Irilis75',
#  'Shidai42',
#  'Mindesi74',
#  'Sondim73',
#  'Ealrion88',
#  'Hiaral50',
#  'Yalostiphos68',
#  'Iskosian40',
#  'Lirtim36',
#  'Haedairiadru51',
#  'Jiskjask80',
#  'Yarithsurgue62',
#  'Ethrasyon38',
#  'Alaesu91',
#  'Yana46',
#  'Haisrisuir60',
#  'Rastynusuir31',
#  'Philodil43',
#  'Quinarap53',
#  'Ilaesudil92',
#  'Phistyn52',
#  'Aenarap34',
#  'Chamirraya83',
#  'Quaranmol58',
#  'Layjask75',
#  'Haellysu29',
#  'Hyaduesu61',
#  'Lalossa38',
#  'Yarithrin84',
#  'Malunil62',
#  'Chanastsda67',
#  'Phistym51',
#  'Shaidanu32',
#  'Jiskjask60',
#  'Undirra73',
#  'Saena74',
#  'Chanosia34',
#  'Iana95',
#  'Siana77',
#  'Saesrideu94',
#  'Iadueria43',
#  'Eurithphos97',
#  'Ardcil81',
#  'Frichadar89',
#  'Lisirra25',
#  'Tyananurgue44',
#  'Lassimla92',
#  'Inasuir29',
#  'Saisrilis27',
#  'Palyon91',
#  'Lassassast73',
#  'Lirtastsya71',
#  'Sondistanya61',
#  'Bartassaya73',
#  'Qilalista41',
#  'Marassa62',
#  'Hallysucal81',
#  'Ennoncil86',
#  'Chanista95',
#  'Lisosia93',
#  'Tyeosri53',
#  'Heosurnuru52',
#  'Yathecal72',
#  'Chanastnya43',
#  'Sondossa69',
#  'Indonmol95',
#  'Chamadarnya73',
#  'Idaisuir85',
#  'Mindadaran26',
#  'Raysistast71',
#  'Eodaisu60',
#  'Salilis27',
#  'Chanadar44',
#  'Undare39',
#  'Pheosrinudeu70',
#  'Tyeoralru41',
#  'Frichynde86',
#  'Isurria36',
#  'Hiral75',
#  'Yadaisuir65',
#  'Arin32',
#  'Iduelis31',
#  'Pheulidil31',
#  'Rianistast50',
#  'Jiskassa76',
#  'Ithergue48',
#  'Lassjaskan73',
#  'Lisopela58',
#  'Iaralrgue74',
#  'Alim85',
#  'Assesi91',
#  'Heudai45',
#  'Chamast86',
#  'Chanilsast61',
#  'Pheusrical25',
#  'Assjaskan73',
#  'Chanjask65',
#  'Eolan54',
#  'Chanastst38',
#  'Lirtosia63',
#  'Frichirranya75',
#  'Mindista32',
#  'Sondadarya58',
#  'Quarrion42',
#  'Umolrian85',
#  'Assehoan67',
#  'Iljask75',
#  'Phaelap26',
#  'Assylla81',
#  'Hirirap39',
#  'Poshilsa82',
#  'Maradarnya40',
#  'Tyidaim51',
#  'Marirrasta50',
#  'Itheria73',
#  'Sondimla25',
#  'Firatan58',
#  'Aerillorin70',
#  'Lisirra87',
#  'Ina92',
#  'Sondim68',
#  'Tyaelaelis94',
#  'Yadaphos40',
#  'Lassjask63',
#  'Phiristi62',
#  'Mindilsa34',
#  'Meosridil82',
#  'Lassassasda30',
#  'Lirtilsa71',
#  'Ilista82',
#  'Chamistast30',
#  'Aisurdru79',
#  'Frichaya88',
#  'Sida61',
#  'Eoral49',
#  'Hari50',
#  'Tyarithn67',
#  'Haerithp41',
#  'Assastnya25',
#  'Maluncil97',
#  'Maridisya31',
#  'Lisassala98',
#  'Seosrim97',
#  'Rairin89',
#  'Idaidil28',
#  'Chanjaskan89',
#  'Assassasta79',
#  'Eulaestira36',
#  'Chamadarsda63',
#  'Eyrian71',
#  'Jiskadarst60',
#  'Leyirra83',
#  'Siarithria38',
#  'Heollyriap59',
#  'Asur96',
#  'Euthe35',
#  'Aeral68',
#  'Minduli80',
#  'Frichadaran88',
#  'Tyalaesu89',
#  'Yalo85',
#  'Frichast28',
#  'Ethron58',
#  'Ilirrasda54',
#  'Lirtastan49',
#  'Chamalo71',
#  'Assistasda42',
#  'Aerithllora36',
#  'Isursti83',
#  'Iral74',
#  'Chanilsasda38',
#  'Lisosia66',
#  'Lirtassan78',
#  'Risty84',
#  'Lisasi93',
#  'Tyaenasti87',
#  'Aithelis62',
#  'Ilunyon70',
#  'Eusri26',
#  'Isursuir31',
#  'Sastydeu50',
#  'Tyisur83',
#  'Aestysu37',
#  'Jeyciman68',
#  'Irillo49',
#  'Zhisrisu83',
#  'Lirtirra37',
#  'Rilaera56',
#  'Jiskjask85',
#  'Wailin72',
#  'Zontibe81',
#  'Lirtossa60',
#  'Tyialisudeu65',
#  'Seolollo93',
#  'Yasur35',
#  'Iathenudil29',
#  'Hariphos58',
#  'Marundi65',
#  'Aeral97',
#  'Marilsasya33',
#  'Aelaria33',
#  'Sundassa93',
#  'Lisjaskya84',
#  'Hisridru55',
#  'Haillyrgue51',
#  'Aiduecal76',
#  'Isri34',
#  'Eusurdeu49',
#  'Minduri31',
#  'Qilatista90',
#  'Tyaedainu44',
#  'Syally44',
#  'Undosia27',
#  'Aesur96',
#  'Reunasu60',
#  'Chamassasya86',
#  'Eoralrap26',
#  'Lirtassa52',
#  'Seuthep89',
#  'Lamil79',
#  'Frichaststa61',
#  'Yadacal26',
#  'Liawista80',
#  'Aidaira26',
#  'Chamadar79',
#  'Quaecjask96',
#  'Frichocesta66',
#  'Strithenu87',
#  'Tyidainu31',
#  'Siallylis44',
#  'Farusrian86',
#  'Eudanu32',
#  'Qilunan34',
#  'Aiduesu86',
#  'Yarithllodeu72',
#  'Hilaerin92',
#  'Ingatcil75',
#  'Smaistysu35',
#  'Undilsan50',
#  'Phaedue89',
#  'Lisassasta50',
#  'Tyaelly53',
#  'Eulasuir89',
#  'Chanastya70',
#  'Silaera56',
#  'Tyaelo67',
#  'Mindirranya33',
#  'Lisossanya98',
#  'Mindossa76',
#  'Eratiel90',
#  'Frichim77',
#  'Sondadar26',
#  'Eudanu84',
#  'Seudaillorap38',
#  'Ristydru66',
#  'Rairith81',
#  'Iskossasda43',
#  'Assim27',
#  'Peorith44',
#  'Eustyria89',
#  'Frichossala54',
#  'Lisassa64',
#  'Ealiril69',
#  'Aelastirin39',
#  'Chamossa77',
#  'Sondassasya91',
#  'Raisty38',
#  'Ilosian36',
#  'Qilanrion65',
#  'Lisossa25',
#  'Hiasurria41',
#  'Lisast87',
#  'Yarolwen77',
#  'Hala31',
#  'Aesurstilis64',
#  'Lassilsala30',
#  'Phiarithdeu40',
#  'Hada39',
#  'Mindetosya30',
#  'Aerithriaphos45',
#  'Aina42',
#  'Maradaran90',
#  'Iasurriacal29',
#  'Yasrisu92',
#  'Ethralista69',
#  'Aelidru27',
#  'Leetirraya83',
#  'Aeralria27',
#  'Ili43',
#  'Lisjaskan36',
#  'Ririp86',
#  'Iskirra45',
#  'Frichosiala98',
#  'Indcil77',
#  'Ryanara76',
#  'Isty55',
#  'Mindjasksya61',
#  'Eryon48',
#  'Adairialis76',
#  'Chadadarla74',
#  'Rarallo90',
#  'Sundim98',
#  'Ialidru40',
#  'Chanirra79',
#  'Thryallym62',
#  'Ililsasya43',
#  'Pheodaisun84',
#  'Chanosia60',
#  'Eosurdru76',
#  'Adastirin33',
#  'Ethriel85',
#  'Aidai73',
#  'Alarap40',
#  'Aidai61',
#  'Indirrian56',
#  'Tyeudariasuir90',
#  'Chamiman85',
#  'Taeduenu92',
#  'Sundista37',
#  'Lisista54',
#  'Chanosiaya39',
#  'Yadam35',
#  'Aellyria80',
#  'Ilassa51',
#  'Ilastilis78',
#  'Eyircil84',
#  'Lisiriya82',
#  'Maropast28',
#  'Lirtimst73',
#  'Nitherian58',
#  'Ennalmol65',
#  'Aeral43',
#  'Aerithriaphos46',
#  'Ardonmol96',
#  'Firan91',
#  'Marilsanya48',
#  'Chadjask85',
#  'Marilsa69',
#  'Ali84',
#  'Lirtirra81',
#  'Thourdirra92',
#  'Chadista79',
#  'Phiallylis33',
#  'Ialallo29',
#  'Chanosian48',
#  'Thrientossa55',
#  'Syathe73',
#  'Yadanu52',
#  'Chamjaskya75',
#  'Chadjask77',
#  'Aerithnuphos61',
#  'Ilosianya35',
#  'Tyaelistidru84',
#  'Syathecal44',
#  'Aela59',
#  'Ilast79',
#  'Aeda94',
#  'Filrion83',
#  'Iasursti71',
#  'Aelin32',
#  'Chanirrala39',
#  'Undimsya85',
#  'Styaduen40',
#  'Lisilsa62',
#  'Ermol76',
#  'Yoishirrala98',
#  'Malil90',
#  'Ilarin91',
#  'Chanossast57',
#  'Quilassa66',
#  'Yathedeu43',
#  'Hiasri33',
#  'Saida58',
#  'Tyeurith29',
#  'Iasur80',
#  'Iaralsuir44',
#  'Aerithnucal56',
#  'Yaliru88',
#  'Marughi89',
#  'Sisur91',
#  'Saerallora71',
#  'Cosadar58',
#  'Assosia88',
#  'Marokian45',
#  'Marim28',
#  'Quanunwen42',
#  'Phyali88',
#  'Sundadar27',
#  'Laedallo55',
#  'Tyirinu79',
#  'Sondilsaya62',
#  'Alaephos75',
#  'Chamastya76',
#  'Eurisuru25',
#  'Halaecal66',
#  'Lirtastsda29',
#  'Aina43',
#  'Chadolyla44',
#  'Chadirra90',
#  'Sundjask71',
#  'Lisovynya38',
#  'Phaena87',
#  'Iasrira89',
#  'Irith83',
#  'Lisossala30',
#  'Lisim78',
#  'Eusri44',
#  'Rithe53',
#  'Heuli25',
#  'Phaestycal84',
#  'Lisossa46',
#  'Ennrian78',
#  'Iskadarya95',
#  'Eulae84',
#  'Caesrinusuir82',
#  'Siala43',
#  'Irithlis29',
#  'Iarilis73',
#  'Haeladil46',
#  'Yalaeria91',
#  'Mindimnya67',
#  'Undjaskla97',
#  'Frichjaskan98',
#  'Aillyrin83',
#  'Aethedru70',
#  'Yasur85',
#  'Jiskirran77',
#  'Lisista63',
#  'Sundadarla27',
#  'Assilsan72',
#  'Hiarideu73',
#  'Frichilsa31',
#  'Aelly27',
#  'Eyista89',
#  'Jiskimya77',
#  'Assjaskan56',
#  'Chamirra53',
#  'Quanenrian83',
#  'Idacal95',
#  'Dyally87',
#  'Lisast98',
#  'Lirtilsa72',
#  'Yalae81',
#  'Iathem87',
#  'Yathecal82',
#  'Chamilsala65',
#  'Saelaephos52',
#  'Ilimya66',
#  'Undotesta33',
#  'Aeri84',
#  'Aisur51',
#  'Saistyphos30',
#  'Assistasda90',
#  'Sidap51',
#  'Tyida79',
#  'Yastyriaphos75',
#  'Eusri70',
#  'Lisassasda39',
#  'Raillydeu47',
#  'Chadilsasta32',
#  'Airi27',
#  'Raesty92',
#  'Aelollo59',
#  'Frichjask31',
#  'Aillyriadru65',
#  'Palatyon26',
#  'Alo38',
#  'Lirtistanya48',
#  'Eulanurin88',
#  'Tyeuduen32',
#  'Farrian71',
#  'Iskichinya81',
#  'Ilmol66',
#  'Chadistaya75',
#  'Iduenu77',
#  'Haisurra41',
#  'Aellynun67',
#  'Chanuchi25',
#  'Inguron55',
#  'Qarirwen82',
#  'Frichosia58',
#  'Tyaelorap29',
#  'Sondassan80',
#  'Pheodai94',
#  'Aidain51',
#  'Baelollodeu94',
#  'Anallorgue57',
#  'Marast30',
#  'Ililsan66',
#  'Chamimla85',
#  'Lassirrasda85',
#  'Phaedasurap84',
#  'Iskjaskst81',
#  'Assirra56',
#  'Lisirra58',
#  'Ceoral34',
#  'Chamjask73',
#  'Lassadarsda57',
#  'Idairin51',
#  'Ilosia37',
#  'Errian63',
#  'Aidai53']
